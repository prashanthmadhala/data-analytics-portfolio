# %%
import pandas as pd

# Load dataset
df = pd.read_csv(link to the filepath)

# %%
#Check the first few rows of the dataframe df
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  d70442bc5e3cb7438da497cc6a210f80  10a79ef2783cae3d8d678e85fde235ac
# 1  b669dc3736aa7bf3f5f181f9f460dde5  237cd40f8611065ccaee3db2484eedaa
# 2  f4a8925490afed995d0e987c48908d2c  26b73fb8069041c193a5001e01fcccfd
# 3  3e72677344408fece35547ac4c8ebb94  bd4a8885eb34fde35641c041de257375
# 4  68dd7c23e8b6c1e5f3ad16be5dd4bdf6  175f8430de932f744f8eebc3c680915e
#
#                  customer_unique_id customer_city customer_state  \
# 0  21dbe8eabd00b34492a939c540e2b1a7     sao paulo             SP
# 1  4e1be68fdb65f1ffe1cb79ce38da2a84     guarulhos             SP
# 2  a9a01f767af5be3c3666cf307d5f790f     sao paulo             SP
# 3  faa906cd93e9c6017fc5e6f885f3a05c     sao paulo             SP
# 4  41d57ab847e5ccbe403f46b07ee577d6         cotia             SP
#
#    customer_zip_code_prefix                        product_id  \
# 0                      2413  9a8706b8c060b16e5f0d2925f20bc35b
# ...

# %%
# Get the unique list of customer states
unique_states = df['customer_state'].unique()

# Print the unique states
print("Unique customer states:")
print(unique_states)
# Out:
# Unique customer states:
# ['SP' 'PR' 'SC' 'MG' 'RJ' 'RS' 'PE' 'DF' 'BA' 'ES' 'GO' 'MS' 'RN' 'AM'
#  'PB' 'SE' 'MT' 'PI' 'PA' 'CE' 'AL' 'MA' 'AC' 'TO' 'RR' 'AP' 'RO']

# %%
#Now we will replace the short names of customer_state with original names of different Brazilian states 
brazil_states = {
    "SP": "São Paulo",
    "PR": "Paraná",
    "SC": "Santa Catarina",
    "MG": "Minas Gerais",
    "RJ": "Rio de Janeiro",
    "RS": "Rio Grande do Sul",
    "PE": "Pernambuco",
    "DF": "Distrito Federal",
    "BA": "Bahia",
    "ES": "Espírito Santo",
    "GO": "Goiás",
    "MS": "Mato Grosso do Sul",
    "RN": "Rio Grande do Norte",
    "AM": "Amazonas",
    "PB": "Paraíba",
    "SE": "Sergipe",
    "MT": "Mato Grosso",
    "PI": "Piauí",
    "PA": "Pará",
    "CE": "Ceará",
    "AL": "Alagoas",
    "MA": "Maranhão",
    "AC": "Acre",
    "TO": "Tocantins",
    "RR": "Roraima",
    "AP": "Amapá",
    "RO": "Rondônia"
}

# %%
# Replace customer_state abbreviations with full names
df['customer_state'] = df['customer_state'].replace(brazil_states)

# Verify the replacement
print("Updated customer_state column with full names:")
print(df['customer_state'].unique())
# Out:
# Updated customer_state column with full names:
# ['São Paulo' 'Paraná' 'Santa Catarina' 'Minas Gerais' 'Rio de Janeiro'
#  'Rio Grande do Sul' 'Pernambuco' 'Distrito Federal' 'Bahia'
#  'Espírito Santo' 'Goiás' 'Mato Grosso do Sul' 'Rio Grande do Norte'
#  'Amazonas' 'Paraíba' 'Sergipe' 'Mato Grosso' 'Piauí' 'Pará' 'Ceará'
#  'Alagoas' 'Maranhão' 'Acre' 'Tocantins' 'Roraima' 'Amapá' 'Rondônia']

# %%
# Convert timestamp columns to datetime
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])

# %%
# 1. Total number of orders based on order_id
total_orders = df['order_id'].nunique()
print(f'Total number of orders: {total_orders}')
# Out:
# Total number of orders: 7528

# %%
# 2. Total number of unique customers based on customer_unique_id
total_unique_customers = df['customer_unique_id'].nunique()
print(f'Total number of unique customers (customer_unique_id): {total_unique_customers}')
# Out:
# Total number of unique customers (customer_unique_id): 7339

# %%
# 3. Total number of unique customers based on customer_id
total_customers = df['customer_id'].nunique()
print(f'Total number of unique customers (customer_id): {total_customers}')
# Out:
# Total number of unique customers (customer_id): 7528

# %%
# 4. Total number of products bought by each customer
customer_product_counts = df.groupby('customer_unique_id')['order_id'].count().value_counts()
print('Number of customers by number of orders:')
print(customer_product_counts)
# Out:
# Number of customers by number of orders:
# order_id
# 1     6866
# 2      403
# 3       46
# 4       12
# 6        5
# 5        2
# 7        2
# 9        1
# 10       1
# 12       1
# Name: count, dtype: int64

# %%
# 5. Total number of unique customers from each customer_city
unique_customers_by_city = df.groupby('customer_city')['customer_unique_id'].nunique().sort_values(ascending=False)
print('Total unique customers by city (in descending order):')
print(unique_customers_by_city)
# Out:
# Total unique customers by city (in descending order):
# customer_city
# sao paulo         1193
# rio de janeiro     485
# belo horizonte     182
# brasilia           182
# curitiba           130
#                   ...
# itanhomi             1
# itapetinga           1
# itapolis             1
# itapui               1
# ze doca              1
# Name: customer_unique_id, Length: 1366, dtype: int64

# %%
import matplotlib.pyplot as plt

# Total unique customers by city (descending order)
unique_customers_by_city = df.groupby('customer_city')['customer_unique_id'].nunique().sort_values(ascending=False)

# Select the top 15 cities
top_15_cities = unique_customers_by_city.head(15)

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(top_15_cities.index, top_15_cities.values, edgecolor='black', linewidth=1.5)

# Add labels and title
plt.title('Top 15 Cities by Total Unique Customers', fontsize=16)
plt.xlabel('Customer City', fontsize=12)
plt.ylabel('Number of Unique Customers', fontsize=12)

# Rotate x-axis labels to 90 degrees
plt.xticks(rotation=90, fontsize=10)

# Style the chart for better visuals
for bar in bars:
    bar.set_color('#5DADE2')  # Custom color
    bar.set_edgecolor('black')
    bar.set_linewidth(1.2)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 6. Total number of unique customers from each customer_state
unique_customers_by_state = df.groupby('customer_state')['customer_unique_id'].nunique()
print('Total unique customers by state:')
print(unique_customers_by_state)
# Out:
# Total unique customers by state:
# customer_state
# Acre                      8
# Alagoas                  31
# Amapá                     6
# Amazonas                 12
# Bahia                   242
# Ceará                    87
# Distrito Federal        183
# Espírito Santo          155
# Goiás                   144
# Maranhão                 57
# Mato Grosso              64
# Mato Grosso do Sul       58
# Minas Gerais            825
# Paraná                  408
# Paraíba                  28
# Pará                     70
# Pernambuco              126
# Piauí                    29
# Rio Grande do Norte      20
# Rio Grande do Sul       399
# Rio de Janeiro          883
# Rondônia                 15
# Roraima                   5
# Santa Catarina          303
# Sergipe                  28
# São Paulo              3131
# Tocantins                23
# Name: customer_unique_id, dtype: int64

# %%
# The total unique customers by state
unique_customers_by_state = df.groupby('customer_state')['customer_unique_id'].nunique().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(unique_customers_by_state.index, unique_customers_by_state.values, edgecolor='black', linewidth=1.5)

# Add labels and title
plt.title('Total Unique Customers by State', fontsize=16)
plt.xlabel('Customer State', fontsize=12)
plt.ylabel('Number of Unique Customers', fontsize=12)

# Rotate x-axis labels to 90 degrees
plt.xticks(rotation=90, fontsize=10)

# Style the chart for better visuals
for bar in bars:
    bar.set_color('#76D7C4')  # Custom greenish color
    bar.set_edgecolor('black')
    bar.set_linewidth(1.2)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 7. Number of orders purchased in each month of each year
df['year_month'] = df['order_purchase_timestamp'].dt.to_period('M')
orders_by_month = df.groupby('year_month')['order_id'].count()
print('Number of orders purchased in each month of each year:')
print(orders_by_month)
# Out:
# Number of orders purchased in each month of each year:
# year_month
# 2016-10     18
# 2017-01     64
# 2017-02    147
# 2017-03    182
# 2017-04    194
# 2017-05    273
# 2017-06    261
# 2017-07    360
# 2017-08    392
# 2017-09    423
# 2017-10    450
# 2017-11    557
# 2017-12    464
# 2018-01    607
# 2018-02    592
# 2018-03    679
# 2018-04    546
# 2018-05    469
# 2018-06    391
# 2018-07    432
# 2018-08    442
# Freq: M, Name: order_id, dtype: int64

# %%
# Ensure 'year_month' is sorted and convert to string for plotting
orders_by_month = orders_by_month.sort_index()
orders_by_month.index = orders_by_month.index.astype(str)

# Create a line chart
plt.figure(figsize=(14, 6))
plt.plot(orders_by_month.index, orders_by_month.values, marker='o', linestyle='-', color='#5DADE2', linewidth=2)

# Add title and labels
plt.title('Number of Orders Purchased in Each Month of Each Year', fontsize=16)
plt.xlabel('Year-Month', fontsize=12)
plt.ylabel('Number of Orders', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add data points for better clarity
for x, y in zip(orders_by_month.index, orders_by_month.values):
    plt.text(x, y, str(y), fontsize=8, ha='center', va='bottom')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#7b. # Calculate total sum of price for each month of each year
df['year_month'] = df['order_purchase_timestamp'].dt.to_period('M')
price_by_month = df.groupby('year_month')['price'].sum()
print('Total sum of price for each month of each year:')
print(price_by_month)
# Out:
# Total sum of price for each month of each year:
# year_month
# 2016-10     2033.65
# 2017-01     8397.59
# 2017-02    15527.03
# 2017-03    29914.30
# 2017-04    22843.45
# 2017-05    32404.35
# 2017-06    31619.84
# 2017-07    39242.18
# 2017-08    38346.68
# 2017-09    46029.00
# 2017-10    48661.57
# 2017-11    60025.36
# 2017-12    57460.20
# 2018-01    85320.87
# 2018-02    72042.62
# 2018-03    77945.77
# 2018-04    61939.76
# 2018-05    58651.25
# 2018-06    41638.31
# 2018-07    52068.86
# 2018-08    49563.23
# Freq: M, Name: price, dtype: float64

# %%
# Ensure 'year_month' is sorted and convert to string for plotting
price_by_month = price_by_month.sort_index()
price_by_month.index = price_by_month.index.astype(str)

# Create a line chart
plt.figure(figsize=(14, 6))
plt.plot(price_by_month.index, price_by_month.values, marker='o', linestyle='-', color='#FFB74D', linewidth=2)

# Add title and labels
plt.title('Total Sum of Price in Each Month of Each Year', fontsize=16)
plt.xlabel('Year-Month', fontsize=12)
plt.ylabel('Total Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add data points for better clarity
for x, y in zip(price_by_month.index, price_by_month.values):
    plt.text(x, y, f'{y:,.2f}', fontsize=8, ha='center', va='bottom')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 8. Number of unique customers by payment_type
unique_customers_by_payment_type = df.groupby('payment_type')['customer_unique_id'].nunique()
print('Number of unique customers by payment type:')
print(unique_customers_by_payment_type)
# Out:
# Number of unique customers by payment type:
# payment_type
# boleto         1520
# credit_card    5610
# debit_card      115
# voucher         268
# Name: customer_unique_id, dtype: int64

# %%
# Calculate unique customers by payment type
unique_customers_by_payment_type = df.groupby('payment_type')['customer_unique_id'].nunique()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(unique_customers_by_payment_type.values, 
        labels=unique_customers_by_payment_type.index, 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=plt.cm.Paired.colors, 
        wedgeprops={'edgecolor': 'black'})

# Add a title
plt.title('Unique Customers by Payment Type', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 9. Sum of total price by payment_type
sum_price_by_payment_type = df.groupby('payment_type')['price'].sum()
print('Sum of total price by payment type:')
print(sum_price_by_payment_type)
# Out:
# Sum of total price by payment type:
# payment_type
# boleto         156559.27
# credit_card    718555.10
# debit_card      15441.62
# voucher         41119.88
# Name: price, dtype: float64

# %%
# Calculate the sum of total price by payment type
sum_price_by_payment_type = df.groupby('payment_type')['price'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(sum_price_by_payment_type.index, sum_price_by_payment_type.values, color='#5DADE2', edgecolor='black')

# Add labels and title
plt.title('Sum of Total Price by Payment Type', fontsize=16)
plt.xlabel('Payment Type', fontsize=12)
plt.ylabel('Total Price (Sum)', fontsize=12)

# Add value labels on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:,.2f}', ha='center', va='bottom', fontsize=10)

# Rotate x-axis labels if necessary
plt.xticks(rotation=0, fontsize=10)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 10. Sum of total price for each payment_type across customer_city
sum_price_payment_city = df.groupby(['payment_type', 'customer_city'])['price'].sum()
print('Sum of total price for each payment type across customer city:')
print(sum_price_payment_city)
# Out:
# Sum of total price for each payment type across customer city:
# payment_type  customer_city
# boleto        acopiara                99.00
#               agua boa               199.90
#               agua branca            149.99
#               aguas de lindoia       182.40
#               aguas de sao pedro     229.00
#                                       ...
# voucher       valinhos                59.99
#               valparaiso de goias    169.00
#               viamao                  35.49
#               vila velha             135.80
#               vitoria                159.70
# Name: price, Length: 1981, dtype: float64

# %%
import matplotlib.pyplot as plt

# Group by payment_type and customer_city, summing the price
sum_price_payment_city = df.groupby(['payment_type', 'customer_city'])['price'].sum().reset_index()

# Exclude São Paulo
sum_price_payment_city = sum_price_payment_city[sum_price_payment_city['customer_city'] != 'sao paulo']

# Sort each payment_type by price and get the top 7 cities
top_cities_per_payment_type = (
    sum_price_payment_city
    .sort_values(['payment_type', 'price'], ascending=[True, False])
    .groupby('payment_type')
    .head(7)
)

# Create a bar chart for each payment_type
payment_types = top_cities_per_payment_type['payment_type'].unique()

plt.figure(figsize=(12, 8))

# Iterate over each payment type and create a subplot
for i, payment_type in enumerate(payment_types, 1):
    # Filter the top 7 cities for this payment type
    data = top_cities_per_payment_type[top_cities_per_payment_type['payment_type'] == payment_type]
    
    # Plot bar chart
    plt.subplot(len(payment_types), 1, i)  # One subplot per payment type
    bars = plt.bar(data['customer_city'], data['price'], color='#5DADE2', edgecolor='black')
    
    # Add labels, title, and formatting
    plt.title(f'Top 7 Cities for {payment_type.capitalize()} by Total Price (Excl. São Paulo)', fontsize=14)
    plt.xlabel('Customer City', fontsize=10)
    plt.ylabel('Total Price', fontsize=10)
    plt.xticks(rotation=45, fontsize=8, ha='right')

    # Add gridlines
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Add values on top of the bars
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:,.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
# 11. Sum of total price for each payment_type across customer_state
sum_price_payment_state = df.groupby(['payment_type', 'customer_state'])['price'].sum()
print('Sum of total price for each payment type across customer state:')
print(sum_price_payment_state)
# Out:
# Sum of total price for each payment type across customer state:
# payment_type  customer_state
# boleto        Alagoas                609.59
#               Amapá                   39.00
#               Amazonas               120.30
#               Bahia                 3710.53
#               Ceará                 1087.70
#                                      ...
# voucher       Rio Grande do Sul     1588.29
#               Rio de Janeiro        9377.63
#               Rondônia                49.00
#               Santa Catarina        2052.12
#               São Paulo            18246.94
# Name: price, Length: 92, dtype: float64

# %%
import matplotlib.pyplot as plt

# Group by payment_type and customer_state, summing the price
sum_price_payment_state = df.groupby(['payment_type', 'customer_state'])['price'].sum().reset_index()

# Sort each payment_type by price and get the top states
top_states_per_payment_type = (
    sum_price_payment_state
    .sort_values(['payment_type', 'price'], ascending=[True, False])
    .groupby('payment_type')
    .head(7)  # Show top 7 states for each payment type
)

# Create a bar chart for each payment_type
payment_types = top_states_per_payment_type['payment_type'].unique()

plt.figure(figsize=(12, 8))

# Iterate over each payment type and create a subplot
for i, payment_type in enumerate(payment_types, 1):
    # Filter the top states for this payment type
    data = top_states_per_payment_type[top_states_per_payment_type['payment_type'] == payment_type]
    
    # Plot bar chart
    plt.subplot(len(payment_types), 1, i)  # One subplot per payment type
    bars = plt.bar(data['customer_state'], data['price'], color='#76D7C4', edgecolor='black')
    
    # Add labels, title, and formatting
    plt.title(f'Top 7 States for {payment_type.capitalize()} by Total Price', fontsize=14)
    plt.xlabel('Customer State', fontsize=10)
    plt.ylabel('Total Price', fontsize=10)
    plt.xticks(rotation=45, fontsize=8, ha='right')

    # Add gridlines
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Add values on top of the bars
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:,.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
# 12. Sum of total price that went to each seller_city
sum_price_seller_city = df.groupby('seller_city')['price'].sum()
print('Sum of total price that went to each seller city:')
print(sum_price_seller_city)
# Out:
# Sum of total price that went to each seller city:
# seller_city
# aguas claras df           35.00
# amparo                  1374.87
# anapolis                  69.00
# andradas                 299.90
# aperibe                 1330.36
#                          ...
# tupa                      65.00
# umuarama               11301.19
# vicente de carvalho     1939.54
# vila velha               423.99
# votuporanga            13500.20
# Name: price, Length: 188, dtype: float64

# %%
# Calculate the total price by seller city
sum_price_seller_city = df.groupby('seller_city')['price'].sum().reset_index()

# Sort by total price in descending order and get the top 10 cities
top_seller_cities = sum_price_seller_city.sort_values('price', ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(top_seller_cities['seller_city'], top_seller_cities['price'], color='#FF6F61', edgecolor='black')

# Add labels and title
plt.title('Top 10 Seller Cities by Total Price', fontsize=16)
plt.xlabel('Seller City', fontsize=12)
plt.ylabel('Total Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10, ha='right')

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:,.2f}', ha='center', va='bottom', fontsize=10)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Replace seller_state abbreviations with full names
df['seller_state'] = df['seller_state'].replace(brazil_states)

# Verify the replacement
print("Updated seller_state column with full names:")
print(df['seller_state'].unique())
# Out:
# Updated seller_state column with full names:
# ['São Paulo' 'Paraná' 'Minas Gerais' 'Rio de Janeiro' 'Santa Catarina'
#  'Rio Grande do Sul' 'Goiás' 'Distrito Federal' 'Bahia' 'Espírito Santo'
#  'Pernambuco' 'Rio Grande do Norte' 'Pará' 'Paraíba']

# %%
# 13. Sum of total price that went to each seller_state
sum_price_seller_state = df.groupby('seller_state')['price'].sum()
print('Sum of total price that went to each seller state:')
print(sum_price_seller_state)
# Out:
# Sum of total price that went to each seller state:
# seller_state
# Bahia                    7337.88
# Distrito Federal          424.89
# Espírito Santo           1405.99
# Goiás                   12924.89
# Minas Gerais            34393.34
# Paraná                 168630.15
# Paraíba                   355.00
# Pará                     1238.00
# Pernambuco                390.21
# Rio Grande do Norte       714.20
# Rio Grande do Sul       13663.77
# Rio de Janeiro          56180.26
# Santa Catarina          64220.92
# São Paulo              569796.37
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

# Calculate the sum of total price by seller state
sum_price_seller_state = df.groupby('seller_state')['price'].sum().reset_index()

# Sort by total price in descending order for better visualization
sum_price_seller_state = sum_price_seller_state.sort_values('price', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(sum_price_seller_state['seller_state'], sum_price_seller_state['price'], color='#FFB74D', edgecolor='black')

# Add labels and title
plt.title('Sum of Total Price by Seller State', fontsize=16)
plt.xlabel('Seller State', fontsize=12)
plt.ylabel('Total Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10, ha='right')

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:,.2f}', ha='center', va='bottom', fontsize=10)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  d70442bc5e3cb7438da497cc6a210f80  10a79ef2783cae3d8d678e85fde235ac
# 1  b669dc3736aa7bf3f5f181f9f460dde5  237cd40f8611065ccaee3db2484eedaa
# 2  f4a8925490afed995d0e987c48908d2c  26b73fb8069041c193a5001e01fcccfd
# 3  3e72677344408fece35547ac4c8ebb94  bd4a8885eb34fde35641c041de257375
# 4  68dd7c23e8b6c1e5f3ad16be5dd4bdf6  175f8430de932f744f8eebc3c680915e
#
#                  customer_unique_id customer_city customer_state  \
# 0  21dbe8eabd00b34492a939c540e2b1a7     sao paulo      São Paulo
# 1  4e1be68fdb65f1ffe1cb79ce38da2a84     guarulhos      São Paulo
# 2  a9a01f767af5be3c3666cf307d5f790f     sao paulo      São Paulo
# 3  faa906cd93e9c6017fc5e6f885f3a05c     sao paulo      São Paulo
# 4  41d57ab847e5ccbe403f46b07ee577d6         cotia      São Paulo
#
#    customer_zip_code_prefix                        product_id  \
# 0                      2413  9a8706b8c060b16e5f0d2925f20bc35b
# ...

# %%
#Further analysis

# %%
# Correlation between product_weight_g and freight_value
correlation_weight_freight = df['product_weight_g'].corr(df['freight_value'])
print(f'Correlation between product_weight_g and freight_value: {correlation_weight_freight}')
# Out:
# Correlation between product_weight_g and freight_value: 0.6811878737871616

# %%
#checking significance

from scipy.stats import pearsonr

# Calculate the Pearson correlation coefficient and p-value
correlation, p_value = pearsonr(df['product_weight_g'], df['freight_value'])

print(f'Correlation: {correlation}')
print(f'P-value: {p_value}')

# Interpretation
if p_value < 0.05:
    print('The correlation is statistically significant.')
else:
    print('The correlation is not statistically significant.')
# Out:
# Correlation: 0.6811878737871568
# P-value: 0.0
# The correlation is statistically significant.

# %%
# Correlation between product_length_cm and freight_value
correlation_length_freight = df['product_length_cm'].corr(df['freight_value'])
print(f'Correlation between product_length_cm and freight_value: {correlation_length_freight}')
# Out:
# Correlation between product_length_cm and freight_value: 0.3389723616404388

# %%
# Correlation between product_height_cm and freight_value
correlation_height_freight = df['product_height_cm'].corr(df['freight_value'])
print(f'Correlation between product_height_cm and freight_value: {correlation_height_freight}')
# Out:
# Correlation between product_height_cm and freight_value: 0.40524057448762674

# %%
# Correlation between product_width_cm and freight_value
correlation_width_freight = df['product_width_cm'].corr(df['freight_value'])
print(f'Correlation between product_width_cm and freight_value: {correlation_width_freight}')
# Out:
# Correlation between product_width_cm and freight_value: 0.2776303137766763

# %%
# Total number of payment_installments by payment_type
total_installments_by_payment_type = df.groupby('payment_type')['payment_installments'].sum()
print('Total number of payment_installments by payment type:')
print(total_installments_by_payment_type)
# Out:
# Total number of payment_installments by payment type:
# payment_type
# boleto          1570
# credit_card    17377
# debit_card       116
# voucher          374
# Name: payment_installments, dtype: int64

# %%
# Total number of payment_installments by customer_city in descending order
total_installments_by_city = df.groupby('customer_city')['payment_installments'].sum().sort_values(ascending=False)
print('Cities with the most number of payment_installments (in descending order):')
print(total_installments_by_city)
# Out:
# Cities with the most number of payment_installments (in descending order):
# customer_city
# sao paulo         2753
# rio de janeiro    1301
# belo horizonte     462
# brasilia           442
# salvador           357
#                   ...
# maracaju             1
# maristela            1
# matoes               1
# matutina             1
# laguna               1
# Name: payment_installments, Length: 1366, dtype: int64

# %%
import matplotlib.pyplot as plt

# Calculate the total number of payment_installments by customer_city
total_installments_by_city = df.groupby('customer_city')['payment_installments'].sum()

# Sort in descending order and get the top 10 cities
top_10_cities_installments = total_installments_by_city.sort_values(ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(top_10_cities_installments.index, top_10_cities_installments.values, color='#4DB6AC', edgecolor='black')

# Add labels and title
plt.title('Top 10 Cities with Highest Payment Installments', fontsize=16)
plt.xlabel('Customer City', fontsize=12)
plt.ylabel('Total Payment Installments', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10, ha='right')

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}', ha='center', va='bottom', fontsize=10)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by customer_city and seller_city to find the number of orders and total price exchanged
city_interactions = df.groupby(['customer_city', 'seller_city']).agg(
    total_orders=('order_id', 'count'),
    total_price=('price', 'sum')
).reset_index()

# %%
# Sort the results by total_orders in descending order and select the top 15
top_15_interactions = city_interactions.sort_values(by='total_orders', ascending=False).head(15)

# %%
# Display the top 15 interactions
print('Top 15 interactions between customer_city and seller_city:')
print(top_15_interactions)
# Out:
# Top 15 interactions between customer_city and seller_city:
#        customer_city            seller_city  total_orders  total_price
# 3862       sao paulo              sao paulo           316     28323.85
# 3225  rio de janeiro              sao paulo           104      8695.77
# 3792       sao paulo               curitiba            78     13212.92
# 3839       sao paulo         ribeirao preto            77     10299.21
# 3836       sao paulo           praia grande            67      4501.74
# 3817       sao paulo                    jau            55      5759.40
# 490   belo horizonte              sao paulo            47      4771.54
# 3805       sao paulo                  guara            45      6903.40
# 3866       sao paulo               sorocaba            39       980.32
# 3847       sao paulo  santa barbara d'oeste            38      2894.44
# 656         brasilia              sao paulo            37      3445.64
# ...

# %%
# Prepare data for total_orders
interaction_labels = top_15_interactions.apply(lambda x: f"{x['customer_city']} -> {x['seller_city']}", axis=1)
total_orders = top_15_interactions['total_orders']

# Create the line chart for total_orders
plt.figure(figsize=(12, 6))
plt.plot(interaction_labels, total_orders, marker='o', linestyle='-', color='#4DB6AC', linewidth=2)

# Add data values on the chart
for i, value in enumerate(total_orders):
    plt.text(i, value, f'{value}', fontsize=10, ha='center', va='bottom')

# Add labels and title
plt.title('Top 15 Customer-Seller City Interactions by Total Orders', fontsize=16)
plt.xlabel('Customer -> Seller City', fontsize=12)
plt.ylabel('Number of Orders', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(range(len(interaction_labels)), interaction_labels, rotation=45, fontsize=10, ha='right')

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Prepare data for total_price
total_price = top_15_interactions['total_price']

# Create the line chart for total_price
plt.figure(figsize=(12, 6))
plt.plot(interaction_labels, total_price, marker='o', linestyle='-', color='#FFB74D', linewidth=2)

# Add data values on the chart
for i, value in enumerate(total_price):
    plt.text(i, value, f'{value:,.2f}', fontsize=10, ha='center', va='bottom')

# Add labels and title
plt.title('Top 15 Customer-Seller City Interactions by Total Price', fontsize=16)
plt.xlabel('Customer -> Seller City', fontsize=12)
plt.ylabel('Total Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(range(len(interaction_labels)), interaction_labels, rotation=45, fontsize=10, ha='right')

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
#clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import pandas as pd

# Select relevant features
features = df[['freight_value', 'payment_value', 'payment_sequential', 'payment_installments']]

# %%
# Normalize the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
# Find the optimal number of clusters using the Elbow Method
wcss = []  # Within-cluster sum of squares
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# %%
# Plot the Elbow Method
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method to Determine Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.show()

# %%
# Find the optimal number of clusters using Silhouette Score
silhouette_scores = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    cluster_labels = kmeans.fit_predict(scaled_features)
    silhouette_avg = silhouette_score(scaled_features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot the Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Score to Determine Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
# Choose the optimal number of clusters (based on the plots above)
optimal_clusters = 3  # Adjust this based on the elbow method and silhouette score

# %%
# Apply KMeans clustering
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(scaled_features)

# %%
# Analyze the clusters
print('Cluster centers (scaled values):')
print(kmeans.cluster_centers_)
# Out:
# Cluster centers (scaled values):
# [[-0.13297715 -0.17514447  0.0223868  -0.37874292]
#  [ 5.38239608  4.99400647  0.17258949  1.49850974]
#  [ 0.19188725  0.45527272 -0.13658353  1.88361445]]

# %%
print('\nNumber of customers in each cluster:')
print(df['cluster'].value_counts())
# Out:
# Number of customers in each cluster:
# cluster
# 0    6593
# 2    1231
# 1     119
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  d70442bc5e3cb7438da497cc6a210f80  10a79ef2783cae3d8d678e85fde235ac
# 1  b669dc3736aa7bf3f5f181f9f460dde5  237cd40f8611065ccaee3db2484eedaa
# 2  f4a8925490afed995d0e987c48908d2c  26b73fb8069041c193a5001e01fcccfd
# 3  3e72677344408fece35547ac4c8ebb94  bd4a8885eb34fde35641c041de257375
# 4  68dd7c23e8b6c1e5f3ad16be5dd4bdf6  175f8430de932f744f8eebc3c680915e
#
#                  customer_unique_id customer_city customer_state  \
# 0  21dbe8eabd00b34492a939c540e2b1a7     sao paulo      São Paulo
# 1  4e1be68fdb65f1ffe1cb79ce38da2a84     guarulhos      São Paulo
# 2  a9a01f767af5be3c3666cf307d5f790f     sao paulo      São Paulo
# 3  faa906cd93e9c6017fc5e6f885f3a05c     sao paulo      São Paulo
# 4  41d57ab847e5ccbe403f46b07ee577d6         cotia      São Paulo
#
#    customer_zip_code_prefix                        product_id  \
# 0                      2413  9a8706b8c060b16e5f0d2925f20bc35b
# ...

# %%
# Group by clusters and compute metrics
cluster_metrics = df.groupby('cluster').agg(
    total_customers=('customer_unique_id', 'nunique'),
    avg_freight_value=('freight_value', 'mean'),
    total_freight_value=('freight_value', 'sum'),
    avg_payment_value=('payment_value', 'mean'),
    total_payment_value=('payment_value', 'sum'),
    avg_payment_sequential=('payment_sequential', 'mean'),
    avg_payment_installments=('payment_installments', 'mean'),
    total_orders=('order_id', 'count')
)

# %%
# Add percentage contribution to total freight and payment values
cluster_metrics['pct_total_freight'] = (cluster_metrics['total_freight_value'] / cluster_metrics['total_freight_value'].sum()) * 100
cluster_metrics['pct_total_payment'] = (cluster_metrics['total_payment_value'] / cluster_metrics['total_payment_value'].sum()) * 100

# %%
# Display the metrics
print('Cluster Metrics Analysis:')
print(cluster_metrics)
# Out:
# Cluster Metrics Analysis:
#          total_customers  avg_freight_value  total_freight_value  \
# cluster
# 0                   6112          17.617758            116153.88
# 1                    112         100.739328             11987.98
# 2                   1169          22.513753             27714.43
#
#          avg_payment_value  total_payment_value  avg_payment_sequential  \
# cluster
# 0               114.661580            755963.80                1.069923
# 1              1056.420252            125714.01                1.134454
# 2               229.516198            282534.44                1.001625
#
#          avg_payment_installments  total_orders  pct_total_freight  \
# cluster
# 0                        1.546944          6593          74.526270
# 1                        6.008403           119           7.691688
# 2                        6.923639          1231          17.782041
#
#          pct_total_payment
# cluster
# 0                64.933503
# ...

# %%
cluster_metrics
# Out:
#          total_customers  avg_freight_value  total_freight_value  \
# cluster
# 0                   6112          17.617758            116153.88
# 1                    112         100.739328             11987.98
# 2                   1169          22.513753             27714.43
#
#          avg_payment_value  total_payment_value  avg_payment_sequential  \
# cluster
# 0               114.661580            755963.80                1.069923
# 1              1056.420252            125714.01                1.134454
# 2               229.516198            282534.44                1.001625
#
#          avg_payment_installments  total_orders  pct_total_freight  \
# cluster
# 0                        1.546944          6593          74.526270
# 1                        6.008403           119           7.691688
# 2                        6.923639          1231          17.782041
#
#          pct_total_payment
# cluster
# 0                64.933503
# 1                10.798204
# ...

# %%
"""
# Export cluster metrics to a CSV file
cluster_metrics.to_csv(r"C:\Users\Prashanth\Downloads\data-analytics-portfolio\cluster_metrics.csv", index=True)

# %%
from scipy.stats import f_oneway

# Variables to test
variables = ['freight_value', 'payment_value', 'payment_sequential', 'payment_installments']

# ANOVA for each variable
for var in variables:
    anova_result = f_oneway(*(df[df['cluster'] == cluster][var] for cluster in df['cluster'].unique()))
    print(f"ANOVA for {var}:")
    print(f"F-statistic: {anova_result.statistic:.4f}, P-value: {anova_result.pvalue:.4f}")
    if anova_result.pvalue < 0.05:
        print("=> Significant differences exist between clusters for this variable.\n")
    else:
        print("=> No significant differences between clusters for this variable.\n")
# Out:
# ANOVA for freight_value:
# F-statistic: 3306.4986, P-value: 0.0000
# => Significant differences exist between clusters for this variable.
#
# ANOVA for payment_value:
# F-statistic: 3009.9891, P-value: 0.0000
# => Significant differences exist between clusters for this variable.
#
# ANOVA for payment_sequential:
# F-statistic: 14.9571, P-value: 0.0000
# => Significant differences exist between clusters for this variable.
#
# ANOVA for payment_installments:
# F-statistic: 9377.8914, P-value: 0.0000
# => Significant differences exist between clusters for this variable.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Apply Tukey's HSD for each variable
for var in variables:
    tukey = pairwise_tukeyhsd(endog=df[var], groups=df['cluster'], alpha=0.05)
    print(f"Tukey's HSD Test for {var}:")
    print(tukey)
    print("\n")
# Out:
# Tukey's HSD Test for freight_value:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower    upper  reject
# ----------------------------------------------------
#      0      1  83.1216   0.0  80.7075 85.5356   True
#      0      2    4.896   0.0   4.0856  5.7064   True
#      1      2 -78.2256   0.0 -80.7311  -75.72   True
# ----------------------------------------------------
#
#
# Tukey's HSD Test for payment_value:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj   lower     upper   reject
# --------------------------------------------------------
#      0      1  941.7587   0.0  911.9622  971.5552   True
#      0      2  114.8546   0.0  104.8524  124.8569   True
#      1      2 -826.9041   0.0 -857.8297 -795.9784   True
# --------------------------------------------------------
#
#
# Tukey's HSD Test for payment_sequential:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...

# %%
"""
Freight Value = Cluster 1 has significantly higher freight costs than other clusters.
Payment Value = Cluster 1 spends the most, Cluster 2 spends the least.
Payment Sequential = Cluster 2 differs from Clusters 0 & 1, but Cluster 0 and 1 are similar.
Payment Installments = Cluster 2 uses the most installments, while Cluster 1 prefers one-time payments.
# Out:
#   Cell In[86], line 3
#     - **Cluster 1** has the highest **freight costs** and **payment values**.
#       ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Variables to visualize
variables = ['freight_value', 'payment_value', 'payment_sequential', 'payment_installments']

# Create boxplots for each variable
plt.figure(figsize=(14, 10))
for i, var in enumerate(variables, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='cluster', y=var, data=df, palette='Set2')
    plt.title(f"Distribution of {var} Across Clusters")
    plt.xlabel("Cluster")
    plt.ylabel(var)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Prashanth\AppData\Local\Temp\ipykernel_26024\3167156407.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cluster', y=var, data=df, palette='Set2')
# C:\Users\Prashanth\AppData\Local\Temp\ipykernel_26024\3167156407.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cluster', y=var, data=df, palette='Set2')
# C:\Users\Prashanth\AppData\Local\Temp\ipykernel_26024\3167156407.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cluster', y=var, data=df, palette='Set2')
# ...

# %%
#Now analyzing the freight costs

# %%
# Freight costs by customer state
freight_by_customer_state = df.groupby('customer_state')['freight_value'].mean().sort_values(ascending=False)
print("Average freight cost by customer state:")
print(freight_by_customer_state)

# Freight costs by seller state
freight_by_seller_state = df.groupby('seller_state')['freight_value'].mean().sort_values(ascending=False)
print("Average freight cost by seller state:")
print(freight_by_seller_state)

# Freight costs by customer-seller city pair
freight_by_city_pair = df.groupby(['customer_city', 'seller_city'])['freight_value'].mean().sort_values(ascending=False)
print("Top customer-seller city pairs with the highest freight cost:")
print(freight_by_city_pair.head(10))
# Out:
# Average freight cost by customer state:
# customer_state
# Tocantins              54.521667
# Roraima                48.690000
# Acre                   43.786667
# Rondônia               39.990000
# Paraíba                39.473929
# Rio Grande do Norte    39.210952
# Maranhão               37.320820
# Piauí                  37.145000
# Pará                   35.800137
# Sergipe                35.127000
# Alagoas                32.715625
# Pernambuco             32.390526
# Ceará                  31.832921
# Amazonas               30.550000
# Amapá                  28.058571
# Bahia                  25.317519
# Mato Grosso            25.303433
# Mato Grosso do Sul     22.363750
# Goiás                  22.354258
# Espírito Santo         22.276310
# Minas Gerais           21.477754
# Rio de Janeiro         21.056397
# Distrito Federal       20.712062
# Santa Catarina         20.576888
# Rio Grande do Sul      20.347880
# Paraná                 19.065221
# ...

# %%
import matplotlib.pyplot as plt

# Freight cost by customer state
freight_by_customer_state.plot(kind='bar', figsize=(12, 6))
plt.title('Average Freight Cost by Customer State')
plt.xlabel('Customer State')
plt.ylabel('Average Freight Cost')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Freight cost by seller state
freight_by_seller_state.plot(kind='bar', figsize=(12, 6), color='orange')
plt.title('Average Freight Cost by Seller State')
plt.xlabel('Seller State')
plt.ylabel('Average Freight Cost')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Average freight cost by seller
freight_by_seller = df.groupby('seller_id')['freight_value'].mean().sort_values(ascending=False)
print("Top sellers with the highest average freight cost:")
print(freight_by_seller.head(10))

# Average freight cost by product
freight_by_product = df.groupby('product_id')['freight_value'].mean().sort_values(ascending=False)
print("Top products with the highest average freight cost:")
print(freight_by_product.head(10))
# Out:
# Top sellers with the highest average freight cost:
# seller_id
# 52f976b17ea7f2f087f56dcc419328f6    143.775000
# ccb83a794700270fde70898fe9ff368b    135.601765
# 87b740daf17b5d1be335a64164ec6842    115.205000
# 04aa0a1c5ce6b222003403a3e11c3cc0     98.020000
# e2aee0892199b1d92530e371abd825bf     86.246538
# 099095b050cfe8eb1ddff5317587e96e     83.605000
# 062ce95fa2ad4dfaedfc79260130565f     79.860000
# 612a743d294c27884fb7b80d2b19ba35     76.230000
# cf8ab1616079e2793aa29d524df01bb1     72.926667
# 57d2ba47f7a3209aa347532ae75c1165     70.120000
# Name: freight_value, dtype: float64
# Top products with the highest average freight cost:
# product_id
# 24bf010d82955430eeea5ed7643711c7    293.270000
# 0cf5798cf0a69ca39b286d63dd5a9501    252.350000
# c60da43ed0fc0f33c57242c2f631e99e    233.590000
# dafc867209fb20b8331f1edaebc95b58    218.120000
# 660422061e06da17ca6101e9d6b7aae8    169.120000
# f6a84928571f68635beb0f5c9333c6f3    162.820000
# ...

# %%
# Statistical summary for freight cost by seller
freight_seller_stats = freight_by_seller.describe()
print("Statistical summary of freight cost by seller:")
print(freight_seller_stats)

# Statistical summary for freight cost by product
freight_product_stats = freight_by_product.describe()
print("\nStatistical summary of freight cost by product:")
print(freight_product_stats)
# Out:
# Statistical summary of freight cost by seller:
# count    466.000000
# mean      20.813675
# std       14.487456
# min        5.103333
# 25%       14.401875
# 50%       17.725000
# 75%       21.509545
# max      143.775000
# Name: freight_value, dtype: float64
#
# Statistical summary of freight cost by product:
# count    2821.000000
# mean       20.298886
# std        16.769679
# min         0.820000
# 25%        13.710889
# 50%        16.710000
# 75%        21.400000
# max       293.270000
# Name: freight_value, dtype: float64

# %%
from scipy.stats import zscore

# Calculate Z-scores for freight cost by seller
freight_by_seller_zscores = zscore(freight_by_seller)
outliers_seller = freight_by_seller[freight_by_seller_zscores > 3]  # Threshold Z > 3
print("\nSellers with disproportionately high freight costs (Z > 3):")
print(outliers_seller)

# Calculate Z-scores for freight cost by product
freight_by_product_zscores = zscore(freight_by_product)
outliers_product = freight_by_product[freight_by_product_zscores > 3]  # Threshold Z > 3
print("\nProducts with disproportionately high freight costs (Z > 3):")
print(outliers_product)
# Out:
# Sellers with disproportionately high freight costs (Z > 3):
# seller_id
# 52f976b17ea7f2f087f56dcc419328f6    143.775000
# ccb83a794700270fde70898fe9ff368b    135.601765
# 87b740daf17b5d1be335a64164ec6842    115.205000
# 04aa0a1c5ce6b222003403a3e11c3cc0     98.020000
# e2aee0892199b1d92530e371abd825bf     86.246538
# 099095b050cfe8eb1ddff5317587e96e     83.605000
# 062ce95fa2ad4dfaedfc79260130565f     79.860000
# 612a743d294c27884fb7b80d2b19ba35     76.230000
# cf8ab1616079e2793aa29d524df01bb1     72.926667
# 57d2ba47f7a3209aa347532ae75c1165     70.120000
# 94d76e96eedd976258cd3278ce56d5f2     68.560000
# 989becdce12ebc39863c2bceab6f3ca1     67.130909
# 5d043cd5512d4bd2f88e5ccdd5736c38     64.910000
# Name: freight_value, dtype: float64
#
# Products with disproportionately high freight costs (Z > 3):
# product_id
# 24bf010d82955430eeea5ed7643711c7    293.270000
# 0cf5798cf0a69ca39b286d63dd5a9501    252.350000
# c60da43ed0fc0f33c57242c2f631e99e    233.590000
# ...

# %%
# IQR for freight cost by seller
Q1_seller = freight_by_seller.quantile(0.25)
Q3_seller = freight_by_seller.quantile(0.75)
IQR_seller = Q3_seller - Q1_seller

outliers_seller_iqr = freight_by_seller[freight_by_seller > (Q3_seller + 1.5 * IQR_seller)]
print("\nSellers with disproportionately high freight costs (IQR method):")
print(outliers_seller_iqr)

# IQR for freight cost by product
Q1_product = freight_by_product.quantile(0.25)
Q3_product = freight_by_product.quantile(0.75)
IQR_product = Q3_product - Q1_product

outliers_product_iqr = freight_by_product[freight_by_product > (Q3_product + 1.5 * IQR_product)]
print("\nProducts with disproportionately high freight costs (IQR method):")
print(outliers_product_iqr)
# Out:
# Sellers with disproportionately high freight costs (IQR method):
# seller_id
# 52f976b17ea7f2f087f56dcc419328f6    143.775000
# ccb83a794700270fde70898fe9ff368b    135.601765
# 87b740daf17b5d1be335a64164ec6842    115.205000
# 04aa0a1c5ce6b222003403a3e11c3cc0     98.020000
# e2aee0892199b1d92530e371abd825bf     86.246538
# 099095b050cfe8eb1ddff5317587e96e     83.605000
# 062ce95fa2ad4dfaedfc79260130565f     79.860000
# 612a743d294c27884fb7b80d2b19ba35     76.230000
# cf8ab1616079e2793aa29d524df01bb1     72.926667
# 57d2ba47f7a3209aa347532ae75c1165     70.120000
# 94d76e96eedd976258cd3278ce56d5f2     68.560000
# 989becdce12ebc39863c2bceab6f3ca1     67.130909
# 5d043cd5512d4bd2f88e5ccdd5736c38     64.910000
# f326006815956455b2859abd58fe7e39     61.667500
# 821fb029fc6e495ca4f08a35d51e53a5     60.691905
# 55bb6fe5bebe5012e2d7d9928e1128ff     57.240000
# 24c1de8d9551c0b4fbc53317d53efda8     57.120000
# a7f13822ceb966b076af67121f87b063     53.160000
# ...
